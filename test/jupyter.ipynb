# %%
import websockets
import json
from datetime import datetime, timezone
from time import time as perf_counter
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from config import AIS_API_KEY, AIS_STREAM_URL, AIS_BOUNDING_BOXES

# %%
async def connect_ais_stream():

    ship_names = {}
    
    async with websockets.connect(AIS_STREAM_URL) as websocket:
        subscribe_message = {
            "APIKey": AIS_API_KEY, 
            "BoundingBoxes": AIS_BOUNDING_BOXES
        }
        
        subscribe_message_json = json.dumps(subscribe_message)
        await websocket.send(subscribe_message_json)
        
        message_count = 0
        
        async for message_json in websocket:
            message = json.loads(message_json)
            message_type = message["MessageType"]
            
            if message_type == "ShipStaticData":
                static_data = message.get('Message', {}).get('ShipStaticData', {})
                ship_id = static_data.get('UserID')
                ship_name = static_data.get('Name', '').strip()
                if ship_id and ship_name:
                    was_unknown = ship_id not in ship_names
                    ship_names[ship_id] = ship_name
                    if was_unknown:
                        print(f"Got name for ShipID {ship_id}: {ship_name}")
            
            if message_type == "PositionReport":
                ais_message = message.get('Message', {}).get('PositionReport', {})
                
                if ais_message:
                    message_count += 1
                    
                    ship_id = ais_message.get('UserID', 'N/A')
                    lat = ais_message.get('Latitude', 0)
                    lon = ais_message.get('Longitude', 0)
                    
                    speed = ais_message.get('Sog', None)
                    course = ais_message.get('Cog', None)
                    true_heading = ais_message.get('TrueHeading', None)
                    
                    heading = None if (true_heading is None or true_heading == 511) else true_heading
                    
                    ship_name = ship_names.get(ship_id, 'Unknown')
                    
                    # time_str = datetime.now(timezone.utc).strftime("%H:%M:%S")
                    
                    info_parts = []
                    if speed is not None and speed > 0:
                        info_parts.append(f"Speed: {speed:.1f} kn")
                    if course is not None:
                        info_parts.append(f"Course: {course:.1f}°")
                    if heading is not None:
                        info_parts.append(f"Heading: {heading:.1f}°")
                    
                    info_str = " | ".join(info_parts) if info_parts else ""
                    
                    print(f"[{time_str}] #{message_count:4d} | ShipID: {ship_id:12d} | "
                          f"Name: {ship_name:20s} | "
                          f"Lat: {lat:8.5f}° | Lon: {lon:9.5f}°" + 
                          (f" | {info_str}" if info_str else ""))

await connect_ais_stream()
# Out:
# [15:25:44] #   1 | ShipID:    372594000 | Name: Unknown              | Lat: 13.68784° | Lon: 100.55418° | Course: 0.0° | Heading: 192.0°
# Got name for ShipID 525012169: TB CLEMENT 1
# Got name for ShipID 563105900: PSA MARVEL CS05
# [15:25:44] #   2 | ShipID:    564275000 | Name: Unknown              | Lat:  1.21439° | Lon: 103.88428° | Speed: 8.4 kn | Course: 242.3° | Heading: 244.0°
# [15:25:45] #   3 | ShipID:    477997211 | Name: Unknown              | Lat: 22.28779° | Lon: 114.15967° | Speed: 0.1 kn | Course: 339.0° | Heading: 197.0°
# [15:25:45] #   4 | ShipID:    563086930 | Name: Unknown              | Lat:  1.24422° | Lon: 103.75388° | Speed: 11.3 kn | Course: 56.4° | Heading: 63.0°
# [15:25:45] #   5 | ShipID:    525501277 | Name: Unknown              | Lat: -7.16884° | Lon: 112.69163° | Course: 0.0°
# [15:25:45] #   6 | ShipID:    352006352 | Name: Unknown              | Lat:  1.27510° | Lon: 103.93379° | Course: 284.6° | Heading: 43.0°
# [15:25:45] #   7 | ShipID:    564743000 | Name: Unknown              | Lat:  1.22659° | Lon: 103.77799° | Course: 293.2°
# [15:25:45] #   8 | ShipID:    525025090 | Name: Unknown              | Lat: -7.20445° | Lon: 112.72474° | Course: 52.6°
# [15:25:46] #   9 | ShipID:    567068500 | Name: Unknown              | Lat:  1.26292° | Lon: 103.83737° | Course: 33.5° | Heading: 129.0°
# [15:25:46] #  10 | ShipID:    563060100 | Name: Unknown              | Lat:  1.23178° | Lon: 103.69043° | Speed: 1.4 kn | Course: 8.7°
# [15:25:46] #  11 | ShipID:    563056400 | Name: Unknown              | Lat:  1.27819° | Lon: 103.75289° | Course: 32.9° | Heading: 303.0°
# [15:25:47] #  12 | ShipID:    525901612 | Name: Unknown              | Lat:  1.26316° | Lon: 103.82901° | Course: 24.4°
# [15:25:47] #  13 | ShipID:    636016653 | Name: Unknown              | Lat:  1.29116° | Lon: 103.92607° | Course: 313.7° | Heading: 42.0°
# [15:25:47] #  14 | ShipID:    548024300 | Name: Unknown              | Lat: 10.35335° | Lon: 124.01118° | Course: 360.0°
# [15:25:47] #  15 | ShipID:    477996801 | Name: Unknown              | Lat: 22.29904° | Lon: 114.16711° | Speed: 0.2 kn | Course: 360.0°
# [15:25:47] #  16 | ShipID:    548582800 | Name: Unknown              | Lat: 10.30523° | Lon: 123.91974° | Course: 314.3° | Heading: 229.0°
# [15:25:47] #  17 | ShipID:    477997137 | Name: Unknown              | Lat: 22.28781° | Lon: 114.15864° | Course: 315.3° | Heading: 216.0°
# [15:25:48] #  18 | ShipID:    525007250 | Name: Unknown              | Lat: -7.18197° | Lon: 112.70831° | Speed: 0.1 kn | Course: 360.0°
# Got name for ShipID 477996816: GIC 1
# [15:25:48] #  19 | ShipID:    241406000 | Name: Unknown              | Lat:  1.23957° | Lon: 103.74715° | Course: 178.3° | Heading: 263.0°
# [15:25:48] #  20 | ShipID:    525200068 | Name: Unknown              | Lat: -7.20866° | Lon: 112.72609° | Course: 0.0°
# [15:25:48] #  21 | ShipID:    563060200 | Name: Unknown              | Lat:  1.28869° | Lon: 103.75698° | Speed: 4.2 kn | Course: 106.4° | Heading: 98.0°
# [15:25:48] #  22 | ShipID:    256142000 | Name: Unknown              | Lat:  1.26662° | Lon: 103.79258° | Course: 23.7° | Heading: 32.0°
# [15:25:48] #  23 | ShipID:    477307800 | Name: Unknown              | Lat:  1.26681° | Lon: 103.89081° | Speed: 4.0 kn | Course: 70.0° | Heading: 64.0°
# [15:25:48] #  24 | ShipID:    525022379 | Name: Unknown              | Lat: -6.87745° | Lon: 109.81523° | Speed: 0.4 kn | Course: 39.2°
# [15:25:49] #  25 | ShipID:    477995056 | Name: Unknown              | Lat: 22.30397° | Lon: 114.15581° | Speed: 0.1 kn | Course: 48.0°
# [15:25:49] #  26 | ShipID:    525100990 | Name: Unknown              | Lat: -7.20666° | Lon: 112.73210° | Course: 0.0°
# [15:25:49] #  27 | ShipID:    548696500 | Name: Unknown              | Lat: 10.31089° | Lon: 123.94311° | Course: 74.7°
# [15:25:49] #  28 | ShipID:    525003217 | Name: Unknown              | Lat: -7.19913° | Lon: 112.72855° | Course: 52.3°
# [15:25:49] #  29 | ShipID:    563246900 | Name: Unknown              | Lat:  1.27667° | Lon: 103.89867° | Speed: 6.6 kn | Course: 261.7°
# [15:25:49] #  30 | ShipID:    525003315 | Name: Unknown              | Lat: -7.10750° | Lon: 112.66752° | Speed: 0.2 kn | Course: 32.5°
# [15:25:50] #  31 | ShipID:    525012143 | Name: Unknown              | Lat: -7.18048° | Lon: 112.71463° | Speed: 0.1 kn | Course: 0.0°
# [15:25:50] #  32 | ShipID:    566824000 | Name: Unknown              | Lat:  1.30115° | Lon: 103.96233° | Course: 266.0° | Heading: 47.0°
# [15:25:50] #  33 | ShipID:    477996519 | Name: Unknown              | Lat: 22.32620° | Lon: 114.14764° | Speed: 0.1 kn | Course: 360.0°
# [15:25:51] #  34 | ShipID:    567888882 | Name: Unknown              | Lat: 13.65427° | Lon: 100.55765° | Course: 360.0°
# [15:25:51] #  35 | ShipID:    525003115 | Name: Unknown              | Lat: -7.14830° | Lon: 112.67193° | Speed: 0.1 kn | Course: 59.0°
# [15:25:51] #  36 | ShipID:    538090525 | Name: Unknown              | Lat:  1.13467° | Lon: 103.76332° | Speed: 9.6 kn | Course: 35.0° | Heading: 37.0°
# [15:25:51] #  37 | ShipID:    538010184 | Name: Unknown              | Lat:  1.23084° | Lon: 103.68933° | Speed: 1.4 kn | Course: 8.5° | Heading: 34.0°
# Got name for ShipID 525000111: SARANA
# [15:25:52] #  38 | ShipID:    564671000 | Name: Unknown              | Lat:  1.23129° | Lon: 103.69819° | Speed: 3.4 kn | Course: 224.1° | Heading: 242.0°
# [15:25:52] #  39 | ShipID:    312927000 | Name: Unknown              | Lat: 10.31926° | Lon: 123.95167° | Course: 360.0°
# [15:25:52] #  40 | ShipID:    352006139 | Name: Unknown              | Lat:  1.21471° | Lon: 103.81982° | Speed: 0.1 kn | Course: 182.3° | Heading: 109.0°
# Got name for ShipID 548000014: GRACEFUL STARS
# [15:25:52] #  41 | ShipID:    311054500 | Name: Unknown              | Lat:  1.27194° | Lon: 103.94429° | Course: 286.3° | Heading: 45.0°
# [15:25:53] #  42 | ShipID:    413496590 | Name: Unknown              | Lat: 22.30893° | Lon: 114.15427° | Speed: 0.2 kn | Course: 17.7° | Heading: 80.0°
# [15:25:53] #  43 | ShipID:    567072500 | Name: Unknown              | Lat: 13.70748° | Lon: 100.55931° | Course: 320.8° | Heading: 319.0°
# [15:25:53] #  44 | ShipID:    563033340 | Name: Unknown              | Lat:  1.19124° | Lon: 103.80979° | Speed: 0.4 kn | Course: 121.9°
# [15:25:53] #  45 | ShipID:    566010000 | Name: Unknown              | Lat:  1.14584° | Lon: 103.75229° | Speed: 17.5 kn | Course: 239.0° | Heading: 242.0°
# Got name for ShipID 525901875: MT LUMENA 68
# [15:25:53] #  46 | ShipID:    477995428 | Name: Unknown              | Lat: 22.29336° | Lon: 114.16860° | Speed: 0.2 kn | Course: 346.0°
# [15:25:54] #  47 | ShipID:    477385000 | Name: Unknown              | Lat: 22.28793° | Lon: 114.15243° | Speed: 0.1 kn | Course: 0.0° | Heading: 105.0°
# [15:25:54] #  48 | ShipID:    563075940 | Name: Unknown              | Lat:  1.26566° | Lon: 103.83314° | Speed: 2.1 kn | Course: 84.8° | Heading: 101.0°
# [15:25:54] #  49 | ShipID:    565378000 | Name: Unknown              | Lat:  1.23765° | Lon: 103.87048° | Speed: 19.5 kn | Course: 130.6°
# [15:25:54] #  50 | ShipID:    413622280 | Name: Unknown              | Lat: 22.30907° | Lon: 114.12239° | Course: 59.7° | Heading: 13.0°
# Got name for ShipID 548522500: MV  AKIRA
# [15:25:54] #  51 | ShipID:    565112000 | Name: Unknown              | Lat:  1.21870° | Lon: 103.80857° | Speed: 0.1 kn | Course: 19.4° | Heading: 102.0°
# [15:25:54] #  52 | ShipID:    563275600 | Name: Unknown              | Lat:  1.22951° | Lon: 103.68455° | Course: 224.2° | Heading: 257.0°
# [15:25:54] #  53 | ShipID:    563086590 | Name: Unknown              | Lat:  1.25525° | Lon: 103.78496° | Speed: 0.1 kn | Course: 298.5° | Heading: 313.0°
# Got name for ShipID 413496590: ZHONG SHAN 6
# [15:25:55] #  54 | ShipID:    563085890 | Name: Unknown              | Lat:  1.18688° | Lon: 103.79767° | Speed: 10.4 kn | Course: 236.2° | Heading: 235.0°
# [15:25:55] #  55 | ShipID:    305168000 | Name: Unknown              | Lat:  1.13802° | Lon: 103.77545° | Speed: 7.7 kn | Course: 52.4° | Heading: 54.0°
# [15:25:56] #  56 | ShipID:    668116289 | Name: Unknown              | Lat:  1.21564° | Lon: 103.79812° | Speed: 7.8 kn | Course: 122.2°
# [15:25:56] #  57 | ShipID:    525005319 | Name: Unknown              | Lat: -7.18962° | Lon: 112.69036° | Course: 130.5°
# [15:25:56] #  58 | ShipID:    563069100 | Name: Unknown              | Lat:  1.26754° | Lon: 103.87775° | Course: 185.8° | Heading: 41.0°
# [15:25:56] #  59 | ShipID:    563273700 | Name: Unknown              | Lat:  1.24279° | Lon: 103.79885° | Speed: 0.1 kn | Course: 340.5° | Heading: 49.0°
# [15:25:56] #  60 | ShipID:    558800300 | Name: Unknown              | Lat: 10.30185° | Lon: 123.91579° | Course: 360.0°
# [15:25:57] #  61 | ShipID:    574379000 | Name: Unknown              | Lat:  1.23097° | Lon: 103.79655° | Course: 299.3°
# [15:25:57] #  62 | ShipID:    567001640 | Name: Unknown              | Lat: 13.65441° | Lon: 100.55717° | Course: 360.0°
# [15:25:57] #  63 | ShipID:    416012000 | Name: Unknown              | Lat: 25.30985° | Lon: 121.19127° | Speed: 12.6 kn | Course: 278.0° | Heading: 282.0°
# Got name for ShipID 563034300: MARINE ROSE
# [15:25:58] #  64 | ShipID:    566000060 | Name: Unknown              | Lat:  1.25622° | Lon: 103.83956° | Course: 0.0°
# [15:25:58] #  65 | ShipID:    563066530 | Name: Unknown              | Lat:  1.23039° | Lon: 103.68921° | Speed: 1.5 kn | Course: 12.1°
# [15:25:58] #  66 | ShipID:    525015894 | Name: Unknown              | Lat: -7.18102° | Lon: 112.71294° | Speed: 0.1 kn | Course: 145.4°
# Got name for ShipID 564735000: INFINITY
# [15:25:58] #  67 | ShipID:    548054900 | Name: Unknown              | Lat: 10.33463° | Lon: 123.98245° | Speed: 0.3 kn | Course: 356.2° | Heading: 233.0°
# [15:25:59] #  68 | ShipID:    533132085 | Name: Unknown              | Lat:  1.19970° | Lon: 103.57910° | Speed: 13.4 kn | Course: 284.2° | Heading: 285.0°
# [15:25:59] #  69 | ShipID:    413493570 | Name: Unknown              | Lat: 22.30418° | Lon: 114.12595° | Course: 360.0° | Heading: 79.0°
# [15:25:59] #  70 | ShipID:    548295100 | Name: Unknown              | Lat: 10.34609° | Lon: 123.99520° | Course: 360.0°
# [15:25:59] #  71 | ShipID:    563147600 | Name: Unknown              | Lat:  1.25879° | Lon: 103.76792° | Speed: 8.7 kn | Course: 319.8°
# [15:25:59] #  72 | ShipID:    538005751 | Name: Unknown              | Lat:  1.19073° | Lon: 103.64539° | Speed: 12.9 kn | Course: 283.2° | Heading: 285.0°
# [15:26:00] #  73 | ShipID:    457900538 | Name: Unknown              | Lat: 10.31498° | Lon: 123.94882° | Course: 360.0°
# Got name for ShipID 413495990: ZHENYUAN393
# Got name for ShipID 246472000: NILE RIVER
# [15:26:00] #  74 | ShipID:    525005054 | Name: Unknown              | Lat: -7.19633° | Lon: 112.73344° | Course: 221.0° | Heading: 260.0°
# [15:26:00] #  75 | ShipID:    533150045 | Name: Unknown              | Lat:  1.17553° | Lon: 103.52809° | Speed: 6.3 kn | Course: 88.7° | Heading: 85.0°
# [15:26:00] #  76 | ShipID:    563132700 | Name: Unknown              | Lat:  1.25953° | Lon: 103.78895° | Course: 308.9° | Heading: 31.0°
# [15:26:01] #  77 | ShipID:    548522500 | Name: MV  AKIRA            | Lat: 10.31092° | Lon: 123.92744° | Course: 360.0°
# [15:26:01] #  78 | ShipID:    311048900 | Name: Unknown              | Lat:  1.18779° | Lon: 103.78894° | Course: 260.6° | Heading: 60.0°
# [15:26:01] #  79 | ShipID:    636016118 | Name: Unknown              | Lat:  1.28822° | Lon: 103.75727° | Speed: 3.9 kn | Course: 113.4° | Heading: 120.0°
# Got name for ShipID 525125008: MERATUS LABUAN BAJO
# [15:26:01] #  80 | ShipID:    525014087 | Name: Unknown              | Lat: -7.19483° | Lon: 112.74010° | Course: 180.0° | Heading: 80.0°
# [15:26:01] #  81 | ShipID:    525000011 | Name: Unknown              | Lat: -7.21765° | Lon: 112.72163° | Speed: 0.3 kn | Course: 50.8°
# Got name for ShipID 566000060: SCDF RED MANTA
# [15:26:02] #  82 | ShipID:    525101130 | Name: Unknown              | Lat: -7.18296° | Lon: 112.72510° | Course: 360.0°
# [15:26:02] #  83 | ShipID:    548249900 | Name: Unknown              | Lat: 10.40094° | Lon: 124.00377° | Course: 166.4°
# [15:26:02] #  84 | ShipID:    525601154 | Name: Unknown              | Lat: -7.19824° | Lon: 112.72025° | Course: 227.1°
# [15:26:02] #  85 | ShipID:    525119148 | Name: Unknown              | Lat:  1.26364° | Lon: 103.84359° | Course: 70.1°
# [15:26:02] #  86 | ShipID:    525200263 | Name: Unknown              | Lat: -7.19920° | Lon: 112.72803° | Course: 129.1°
# [15:26:02] #  87 | ShipID:    538012107 | Name: Unknown              | Lat:  1.24937° | Lon: 103.88978° | Course: 139.8° | Heading: 41.0°
# [15:26:02] #  88 | ShipID:    525010246 | Name: Unknown              | Lat: -7.15329° | Lon: 112.66282° | Course: 0.0°
# Got name for ShipID 563882000: MARLIN DUA
# [15:26:04] #  89 | ShipID:    477966600 | Name: Unknown              | Lat:  1.19935° | Lon: 103.79811° | Speed: 0.4 kn | Course: 339.1° | Heading: 78.0°
# [15:26:04] #  90 | ShipID:    441318000 | Name: Unknown              | Lat:  1.24911° | Lon: 103.77520° | Speed: 10.3 kn | Course: 316.2° | Heading: 315.0°
# [15:26:04] #  91 | ShipID:    564886000 | Name: Unknown              | Lat:  1.25635° | Lon: 103.90980° | Course: 24.2° | Heading: 45.0°
# [15:26:04] #  92 | ShipID:    413513310 | Name: Unknown              | Lat:  1.25370° | Lon: 103.87139° | Course: 256.0° | Heading: 36.0°
# [15:26:04] #  93 | ShipID:    567000011 | Name: Unknown              | Lat: 13.70210° | Lon: 100.58012° | Course: 360.0°
# [15:26:04] #  94 | ShipID:    566982000 | Name: Unknown              | Lat:  1.24070° | Lon: 103.87798° | Course: 212.7° | Heading: 44.0°
# Got name for ShipID 525021186: TB SEMAR 82
# [15:26:04] #  95 | ShipID:    566108000 | Name: Unknown              | Lat:  1.22238° | Lon: 103.73344° | Course: 293.7° | Heading: 212.0°
# [15:26:04] #  96 | ShipID:    567001522 | Name: Unknown              | Lat: 13.65587° | Lon: 100.55026° | Course: 360.0°
# [15:26:04] #  97 | ShipID:    525007315 | Name: Unknown              | Lat: -7.11573° | Lon: 112.66270° | Speed: 0.1 kn | Course: 24.5°
# [15:26:05] #  98 | ShipID:    477997196 | Name: Unknown              | Lat: 22.28792° | Lon: 114.15830° | Course: 97.6° | Heading: 181.0°
# Got name for ShipID 566472000: SAFEEN CENTURION 2
# Got name for ShipID 525501972: JENGGALA NASSIM
# [15:26:05] #  99 | ShipID:    305749000 | Name: Unknown              | Lat:  1.25055° | Lon: 103.79876° | Speed: 0.1 kn | Course: 6.9° | Heading: 60.0°
# Got name for ShipID 477997316: WAH FU NO. 108
# [15:26:05] # 100 | ShipID:    525021252 | Name: Unknown              | Lat: -7.19980° | Lon: 112.72486° | Course: 315.0°
# [15:26:05] # 101 | ShipID:    564681000 | Name: Unknown              | Lat:  1.21176° | Lon: 103.80080° | Speed: 5.1 kn | Course: 115.3°
# [15:26:05] # 102 | ShipID:    566753000 | Name: Unknown              | Lat:  1.27769° | Lon: 103.77761° | Course: 135.1° | Heading: 117.0°
# [15:26:05] # 103 | ShipID:    565100000 | Name: Unknown              | Lat: -7.19749° | Lon: 112.72609° | Course: 46.7° | Heading: 81.0°
# [15:26:06] # 104 | ShipID:    563074570 | Name: Unknown              | Lat:  1.26313° | Lon: 103.84375° | Course: 261.7°
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[2], line 65
#      58                     info_str = " | ".join(info_parts) if info_parts else ""
#      60                     print(f"[{time_str}] #{message_count:4d} | ShipID: {ship_id:12d} | "
#      61                           f"Name: {ship_name:20s} | "
#      62                           f"Lat: {lat:8.5f}° | Lon: {lon:9.5f}°" +
#      63                           (f" | {info_str}" if info_str else ""))
# ---> 65 await connect_ais_stream()
#
# Cell In[2], line 16, in connect_ais_stream()
#      12 await websocket.send(subscribe_message_json)
#      14 message_count = 0
# ---> 16 async for message_json in websocket:
#      17     message = json.loads(message_json)
#      18     message_type = message["MessageType"]
#
# File c:\Work\ship-tracer-rt\.venv\Lib\site-packages\websockets\asyncio\connection.py:244, in Connection.__aiter__(self)
#     242 try:
#     243     while True:
# --> 244         yield await self.recv()
#     245 except ConnectionClosedOK:
#     246     return
#
# File c:\Work\ship-tracer-rt\.venv\Lib\site-packages\websockets\asyncio\connection.py:305, in Connection.recv(self, decode)
#     258 """
#     259 Receive the next message.
#     260
#    (...)    302
#     303 """
#     304 try:
# --> 305     return await self.recv_messages.get(decode)
#     306 except EOFError:
#     307     pass
#
# File c:\Work\ship-tracer-rt\.venv\Lib\site-packages\websockets\asyncio\messages.py:158, in Assembler.get(self, decode)
#     153 # Locking with get_in_progress prevents concurrent execution
#     154 # until get() fetches a complete message or is canceled.
#     156 try:
#     157     # Fetch the first frame.
# --> 158     frame = await self.frames.get(not self.closed)
#     159     self.maybe_resume()
#     160     assert frame.opcode is OP_TEXT or frame.opcode is OP_BINARY
#
# File c:\Work\ship-tracer-rt\.venv\Lib\site-packages\websockets\asyncio\messages.py:51, in SimpleQueue.get(self, block)
#      49 self.get_waiter = self.loop.create_future()
#      50 try:
# ---> 51     await self.get_waiter
#      52 finally:
#      53     self.get_waiter.cancel()
#
# CancelledError:
