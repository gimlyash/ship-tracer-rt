# %%
import websockets
from datetime import datetime, timezone
from time import time as perf_counter
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

try:
    import orjson as json
    JSON_LOADS = json.loads
    JSON_DUMPS = lambda x: json.dumps(x).decode('utf-8')
except ImportError:
    import json
    JSON_LOADS = json.loads
    JSON_DUMPS = json.dumps
    print("orjson not installed, using standard json library. Install orjson for better performance.")

from config import AIS_API_KEY, AIS_STREAM_URL, AIS_BOUNDING_BOXES

STATS_INTERVAL = 5 
LOG_DETAILED = False

# %%
async def connect_ais_stream():
    ship_names = {}
    msg_count = 0
    msg_count_interval = 0
    last_stat_time = datetime.now(timezone.utc)
    
    async with websockets.connect(AIS_STREAM_URL) as websocket:
        await websocket.send(JSON_DUMPS({
            "APIKey": AIS_API_KEY, 
            "BoundingBoxes": AIS_BOUNDING_BOXES
        }))
        
        async for message_json in websocket:
            msg_count += 1
            msg_count_interval += 1
            
            message = JSON_LOADS(message_json)
            msg_type = message.get("MessageType")
            
            if msg_type == "ShipStaticData":
                static = message.get("Message", {}).get("ShipStaticData", {})
                mmsi = static.get("UserID")
                name = static.get("Name", "").strip()
                if mmsi and name and mmsi not in ship_names:
                    ship_names[mmsi] = name
                    print(f"New ship {mmsi}: {name}")
            
            elif msg_type == "PositionReport":
                pos = message.get("Message", {}).get("PositionReport", {})
                if not pos:
                    continue
                
                mmsi = pos.get("UserID")
                lat = pos.get("Latitude")
                lon = pos.get("Longitude")
                
                if mmsi is None or lat is None or lon is None:
                    continue
                
                speed = pos.get("Sog", None)
                course = pos.get("Cog", None)
                true_heading = pos.get("TrueHeading", None)
                heading = None if (true_heading is None or true_heading == 511) else true_heading
                
                name = ship_names.get(mmsi, "Unknown")
                
                now = datetime.now(timezone.utc)
                if (now - last_stat_time).total_seconds() >= STATS_INTERVAL:
                    rate = msg_count_interval / STATS_INTERVAL
                    print(
                        f"{now.strftime('%H:%M:%S')} | {rate:.0f} msg/s | "
                        f"Total: {msg_count} | Known ships: {len(ship_names)}"
                    )
                    last_stat_time = now
                    msg_count_interval = 0
                
                if LOG_DETAILED:
                    time_str = now.strftime("%H:%M:%S")
                    info_parts = []
                    if speed is not None and speed > 0:
                        info_parts.append(f"Speed: {speed:.1f} kn")
                    if course is not None:
                        info_parts.append(f"Course: {course:.1f}°")
                    if heading is not None:
                        info_parts.append(f"Heading: {heading:.1f}°")
                    info_str = " | ".join(info_parts) if info_parts else ""
                    
                    print(
                        f"[{time_str}] #{msg_count:4d} | ShipID: {mmsi:12d} | "
                        f"Name: {name:20s} | "
                        f"Lat: {lat:8.5f}° | Lon: {lon:9.5f}°" + 
                        (f" | {info_str}" if info_str else "")
                    )

await connect_ais_stream()
# Out:
# New ship 548000034: M/V BEAUTIFUL STARS
# New ship 565446000: SAVVY
# New ship 565893000: KOTA NAGA
# 10:30:30 | 9 msg/s | Total: 44 | Known ships: 3
# New ship 416036000: EVER BEFIT
# New ship 525125001: MERATUS KARIANGAU
# New ship 419099500: PRABHU SAKHAWAT
# New ship 574001330: BD PIONEER1 _
# New ship 636017404: TYGRA
# New ship 525114005: KRI AHP-355
# New ship 538012107: S-BOUND
# New ship 563075940: PSA CONNECTIVITY
# New ship 636023616: EASTERN URSINIA
# New ship 548173500: LCT-EILEEN
# 10:30:36 | 12 msg/s | Total: 105 | Known ships: 13
# New ship 525019630: WEST POINT
# New ship 525012143: MT.YAN NO.1
# New ship 525020294: AHT TEGAP JAYA
# New ship 477997083: XIN MING ZHU X
# New ship 525100194: MV. SURYA PESONA
# New ship 305485000: SLOMAN THEMIS
# New ship 566373000: CLEANSEAS HARMONY
# 10:30:41 | 9 msg/s | Total: 151 | Known ships: 20
# New ship 477995727: PILOT95
# New ship 525501277: HOKKY 88
# New ship 229358000: APL TURKEY
# New ship 525014220: MT NUSANIWE
# New ship 563079500: CRESCENT RIVER
# 10:30:46 | 10 msg/s | Total: 200 | Known ships: 25
# New ship 538090722: BELLAVISTA EXPLORER
# New ship 352003413: MARINA ARUNG
# New ship 525020363: MV.KABONGA BARU
# New ship 538008339: TOMINI ENTITY
# 10:30:51 | 12 msg/s | Total: 258 | Known ships: 29
# New ship 566981000: KOTA GANDING
# New ship 525125043: MERATUS CIREBON
# New ship 563182900: FUELNG VENOSA
# New ship 563026600: WAVEMASTER 8
# New ship 566540000: ZMAGA
# New ship 413472650: SHENG HANG TIAO ZHAN
# New ship 413800826: TAIZUN38
# 10:30:56 | 9 msg/s | Total: 305 | Known ships: 36
# 10:31:01 | 10 msg/s | Total: 356 | Known ships: 36
# New ship 548522500: MV  AKIRA
# New ship 525010056: ANNABELLA
# New ship 352005716: BROTHER 16
# New ship 352006105: MARINA AURORA
# New ship 525016193: TPS BETA
# New ship 548635300: LCT 198
# New ship 477937500: THE PARISIAN
# New ship 525300005: SPOB MESSI KIANNA 1
# 10:31:06 | 9 msg/s | Total: 402 | Known ships: 44
# New ship 372878000: COREOCEAN OL
# New ship 525005355: KMP.JOKOTOLE
# New ship 548024300: MV KING FREDERICK
# New ship 477997212: HKK 6
# New ship 525101128: KENDHAGA NUSANTARA10
# New ship 525121021: MT ALESSA
# 10:31:11 | 11 msg/s | Total: 456 | Known ships: 50
# New ship 319287300: BETELGEUSE
# New ship 548006500: FILIPINAS BUTUAN
# New ship 636015767: BANDA
# New ship 413334020: MA YUE
# New ship 212451000: GRACE
# 10:31:16 | 10 msg/s | Total: 506 | Known ships: 55
# New ship 312653000: BATAMINDO LEO
# New ship 525801358: PATRIA 46
# New ship 413902762: GUIGANGHUASHENG112
# New ship 477154600: JOSCO SHINE
# 10:31:21 | 11 msg/s | Total: 561 | Known ships: 59
# New ship 538005386: STI PARK
# New ship 413762729: ZHUCHUAN 1002
# 10:31:26 | 10 msg/s | Total: 613 | Known ships: 61
# New ship 563092000: COMO
# New ship 255915565: GLOUCESTER EXPRESS
# New ship 563014980: SYUKUR
# New ship 413210920: HAI XIN YOU 619
# New ship 525015879: DHARMA FERRY VI
# New ship 525007315: KM DEWI SAMUDERA III
# New ship 525022001: KINTAMANI
# New ship 477997043: HUNG HOM
# 10:31:32 | 11 msg/s | Total: 670 | Known ships: 69
# New ship 258030000: BELAJA
# New ship 440044000: SEIN HONOR
# New ship 525107020: HARTATI
# New ship 255915657: FRIDA RUSS
# New ship 563167400: PEARL KATE
# New ship 525021037: CIPTA ANYER
# New ship 563009190: NOBLE JEWEL TG45
# New ship 525015894: MT PANTAI LAMONG
# New ship 477995455: XIN FA
# New ship 440066260: MT.FERIMAS.CAHAYA
# New ship 205670000: INGRID
# New ship 525200723: DHARMA FERRY VII
# 10:31:37 | 13 msg/s | Total: 733 | Known ships: 81
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[7], line 75
#      66                     info_str = " | ".join(info_parts) if info_parts else ""
#      68                     print(
#      69                         f"[{time_str}] #{msg_count:4d} | ShipID: {mmsi:12d} | "
#      70                         f"Name: {name:20s} | "
#      71                         f"Lat: {lat:8.5f}° | Lon: {lon:9.5f}°" +
#      72                         (f" | {info_str}" if info_str else "")
#      73                     )
# ---> 75 await connect_ais_stream()
#
# Cell In[7], line 13, in connect_ais_stream()
#       7 async with websockets.connect(AIS_STREAM_URL) as websocket:
#       8     await websocket.send(JSON_DUMPS({
#       9         "APIKey": AIS_API_KEY,
#      10         "BoundingBoxes": AIS_BOUNDING_BOXES
#      11     }))
# ---> 13     async for message_json in websocket:
#      14         msg_count += 1
#      15         msg_count_interval += 1
#
# File c:\Work\ship-tracer-rt\.venv\Lib\site-packages\websockets\asyncio\connection.py:244, in Connection.__aiter__(self)
#     242 try:
#     243     while True:
# --> 244         yield await self.recv()
#     245 except ConnectionClosedOK:
#     246     return
#
# File c:\Work\ship-tracer-rt\.venv\Lib\site-packages\websockets\asyncio\connection.py:305, in Connection.recv(self, decode)
#     258 """
#     259 Receive the next message.
#     260
#    (...)    302
#     303 """
#     304 try:
# --> 305     return await self.recv_messages.get(decode)
#     306 except EOFError:
#     307     pass
#
# File c:\Work\ship-tracer-rt\.venv\Lib\site-packages\websockets\asyncio\messages.py:158, in Assembler.get(self, decode)
#     153 # Locking with get_in_progress prevents concurrent execution
#     154 # until get() fetches a complete message or is canceled.
#     156 try:
#     157     # Fetch the first frame.
# --> 158     frame = await self.frames.get(not self.closed)
#     159     self.maybe_resume()
#     160     assert frame.opcode is OP_TEXT or frame.opcode is OP_BINARY
#
# File c:\Work\ship-tracer-rt\.venv\Lib\site-packages\websockets\asyncio\messages.py:51, in SimpleQueue.get(self, block)
#      49 self.get_waiter = self.loop.create_future()
#      50 try:
# ---> 51     await self.get_waiter
#      52 finally:
#      53     self.get_waiter.cancel()
#
# CancelledError:
